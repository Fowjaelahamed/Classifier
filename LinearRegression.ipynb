# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
y = df["species"]

# %%
x = df.drop("species",axis = 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=40)

# %%
x_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 100           6.3          3.3           6.0          2.5
# 54            6.5          2.8           4.6          1.5
# 67            5.8          2.7           4.1          1.0
# 97            6.2          2.9           4.3          1.3
# 24            4.8          3.4           1.9          0.2
# 16            5.4          3.9           1.3          0.4
# 96            5.7          2.9           4.2          1.3
# 69            5.6          2.5           3.9          1.1
# 111           6.4          2.7           5.3          1.9
# 133           6.3          2.8           5.1          1.5
# 4             5.0          3.6           1.4          0.2
# 143           6.8          3.2           5.9          2.3
# 61            5.9          3.0           4.2          1.5
# 10            5.4          3.7           1.5          0.2
# 112           6.8          3.0           5.5          2.1
# 45            4.8          3.0           1.4          0.3
# 29            4.7          3.2           1.6          0.2
# 122           7.7          2.8           6.7          2.0
# 47            4.6          3.2           1.4          0.2
# 129           7.2          3.0           5.8          1.6
# 110           6.5          3.2           5.1          2.0
# 20            5.4          3.4           1.7          0.2
# 147           6.5          3.0           5.2          2.0
# 51            6.4          3.2           4.5          1.5
# 32            5.2          4.1           1.5          0.1
# 21            5.1          3.7           1.5          0.4
# 140           6.7          3.1           5.6          2.4
# 27            5.2          3.5           1.5          0.2
# 137           6.4          3.1           5.5          1.8
# 146           6.3          2.5           5.0          1.9
# ..            ...          ...           ...          ...
# 106           4.9          2.5           4.5          1.7
# 35            5.0          3.2           1.2          0.2
# 43            5.0          3.5           1.6          0.6
# 121           5.6          2.8           4.9          2.0
# 87            6.3          2.3           4.4          1.3
# 46            5.1          3.8           1.6          0.2
# 44            5.1          3.8           1.9          0.4
# 60            5.0          2.0           3.5          1.0
# 30            4.8          3.1           1.6          0.2
# 141           6.9          3.1           5.1          2.3
# 99            5.7          2.8           4.1          1.3
# 131           7.9          3.8           6.4          2.0
# 22            4.6          3.6           1.0          0.2
# 104           6.5          3.0           5.8          2.2
# 92            5.8          2.6           4.0          1.2
# 14            5.8          4.0           1.2          0.2
# 8             4.4          2.9           1.4          0.2
# 139           6.9          3.1           5.4          2.1
# 49            5.0          3.3           1.4          0.2
# 73            6.1          2.8           4.7          1.2
# 91            6.1          3.0           4.6          1.4
# 55            5.7          2.8           4.5          1.3
# 74            6.4          2.9           4.3          1.3
# 19            5.1          3.8           1.5          0.3
# 114           5.8          2.8           5.1          2.4
# 71            6.1          2.8           4.0          1.3
# 12            4.8          3.0           1.4          0.1
# 50            7.0          3.2           4.7          1.4
# 7             5.0          3.4           1.5          0.2
# 70            5.9          3.2           4.8          1.8
#
# [100 rows x 4 columns]

# %%
y_train
# Out:
# 100     virginica
# 54     versicolor
# 67     versicolor
# 97     versicolor
# 24         setosa
# 16         setosa
# 96     versicolor
# 69     versicolor
# 111     virginica
# 133     virginica
# 4          setosa
# 143     virginica
# 61     versicolor
# 10         setosa
# 112     virginica
# 45         setosa
# 29         setosa
# 122     virginica
# 47         setosa
# 129     virginica
# 110     virginica
# 20         setosa
# 147     virginica
# 51     versicolor
# 32         setosa
# 21         setosa
# 140     virginica
# 27         setosa
# 137     virginica
# 146     virginica
#           ...
# 106     virginica
# 35         setosa
# 43         setosa
# 121     virginica
# 87     versicolor
# 46         setosa
# 44         setosa
# 60     versicolor
# 30         setosa
# 141     virginica
# 99     versicolor
# 131     virginica
# 22         setosa
# 104     virginica
# 92     versicolor
# 14         setosa
# 8          setosa
# 139     virginica
# 49         setosa
# 73     versicolor
# 91     versicolor
# 55     versicolor
# 74     versicolor
# 19         setosa
# 114     virginica
# 71     versicolor
# 12         setosa
# 50     versicolor
# 7          setosa
# 70     versicolor
# Name: species, Length: 100, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(y_train)
# Out:
# LabelEncoder()

# %%
y_train_new = le.transform(y_train)

# %%
y_train_new
# Out:
# array([2, 1, 1, 1, 0, 0, 1, 1, 2, 2, 0, 2, 1, 0, 2, 0, 0, 2, 0, 2, 2, 0,
#        2, 1, 0, 0, 2, 0, 2, 2, 1, 1, 2, 1, 2, 0, 2, 1, 1, 0, 0, 0, 2, 2,
#        1, 0, 1, 2, 2, 1, 2, 2, 1, 1, 0, 1, 1, 2, 1, 2, 0, 2, 2, 1, 1, 0,
#        2, 1, 0, 1, 2, 0, 0, 2, 1, 0, 0, 1, 0, 2, 1, 2, 0, 2, 1, 0, 0, 2,
#        0, 1, 1, 1, 1, 0, 2, 1, 0, 1, 0, 1])

# %%
from sklearn.linear_model import LinearRegression

# %%
clf = LinearRegression()

# %%
clf.fit(x_train,y_train_new)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_test_new = le.transform(y_test)

# %%
clf.score(x_test,y_test_new)
# Out:
# 0.9428528395444041

# %%
clf.predict([[4.7,3.2,1.3,0.2]])
# Out:
# array([-0.04526125])
